# %% [markdown]
# Welcome to Pycaret tutorial 🌟
# in this tutorial we will learn how to use pycaret to choose the best model for our data
# but first we need to install pycaret
# you can install it by running this command in your terminal:
#
# pip install pycaret

# %% [markdown]
# Now we will try to use pycaret for a classification problem

# %%
# importing the libraries
from pycaret.classification import * 
from pycaret.datasets import get_data   #get_data is a function that will help us to load the data using pycaret

# %%
# You can run this cell if you want to check the dataset get_data function offers 💫
index = get_data('index')

# %% [markdown]
# We will use the glass dataset for this tutorial
# Our goal is to predict the type of glass based on its properties

# %%
# loading the data
data = get_data('glass')
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
# checking the unique values of the target column
data['Type'].unique().tolist()
# Out:
# [1, 2, 3, 5, 6, 7]

# %% [markdown]
# Now to the fun part, we will use pycaret to choose the best model for our data ✨
# pycaret will handle the data splitting, feature engineering, feature selection, and model training for us 🤩

# %%
# setup is a function that will help us to prepare the data for the model 
s = setup(data, target = 'Type', session_id = 123) # session_id is a random number that will help us to save the session so we have the same results when we run the code again
# Out:
# <style type="text/css">
# #T_6deb4_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6deb4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6deb4_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6deb4_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6deb4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6deb4_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6deb4_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_6deb4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6deb4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6deb4_row1_col1" class="data row1 col1" >Type</td>
#     </tr>
#     <tr>
#       <th id="T_6deb4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6deb4_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_6deb4_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_6deb4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6deb4_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_6deb4_row3_col1" class="data row3 col1" >1: 0, 2: 1, 3: 2, 5: 3, 6: 4, 7: 5</td>
#     </tr>
#     <tr>
#       <th id="T_6deb4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6deb4_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_6deb4_row4_col1" class="data row4 col1" >(214, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_6deb4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6deb4_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_6deb4_row5_col1" class="data row5 col1" >(214, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_6deb4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6deb4_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_6deb4_row6_col1" class="data row6 col1" >(149, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_6deb4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6deb4_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_6deb4_row7_col1" class="data row7 col1" >(65, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_6deb4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6deb4_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_6deb4_row8_col1" class="data row8 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_6deb4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6deb4_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_6deb4_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6deb4_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6deb4_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_6deb4_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_6deb4_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6deb4_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_6deb4_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_6deb4_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6deb4_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_6deb4_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_6deb4_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6deb4_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_6deb4_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_6deb4_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6deb4_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_6deb4_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_6deb4_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_6deb4_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_6deb4_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_6deb4_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_6deb4_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_6deb4_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6deb4_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_6deb4_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_6deb4_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6deb4_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_6deb4_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_6deb4_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_6deb4_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_6deb4_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_6deb4_row19_col1" class="data row19 col1" >a538</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The information you see above are the default parameters that pycaret will use for the model, you can change them to fit your needs 😄

# %%
# Now it's time to compare the models
best = compare_models()
# Out:
# <style type="text/css">
# #T_ffe14 th {
#   text-align: left;
# }
# #T_ffe14_row0_col0, #T_ffe14_row1_col0, #T_ffe14_row1_col1, #T_ffe14_row1_col2, #T_ffe14_row1_col3, #T_ffe14_row1_col4, #T_ffe14_row1_col5, #T_ffe14_row1_col6, #T_ffe14_row1_col7, #T_ffe14_row2_col0, #T_ffe14_row2_col1, #T_ffe14_row2_col2, #T_ffe14_row2_col3, #T_ffe14_row2_col4, #T_ffe14_row2_col5, #T_ffe14_row2_col6, #T_ffe14_row2_col7, #T_ffe14_row3_col0, #T_ffe14_row3_col1, #T_ffe14_row3_col2, #T_ffe14_row3_col3, #T_ffe14_row3_col4, #T_ffe14_row3_col5, #T_ffe14_row3_col6, #T_ffe14_row3_col7, #T_ffe14_row4_col0, #T_ffe14_row4_col1, #T_ffe14_row4_col2, #T_ffe14_row4_col3, #T_ffe14_row4_col4, #T_ffe14_row4_col5, #T_ffe14_row4_col6, #T_ffe14_row4_col7, #T_ffe14_row5_col0, #T_ffe14_row5_col1, #T_ffe14_row5_col2, #T_ffe14_row5_col3, #T_ffe14_row5_col4, #T_ffe14_row5_col5, #T_ffe14_row5_col6, #T_ffe14_row5_col7, #T_ffe14_row6_col0, #T_ffe14_row6_col1, #T_ffe14_row6_col2, #T_ffe14_row6_col3, #T_ffe14_row6_col4, #T_ffe14_row6_col5, #T_ffe14_row6_col6, #T_ffe14_row6_col7, #T_ffe14_row7_col0, #T_ffe14_row7_col1, #T_ffe14_row7_col2, #T_ffe14_row7_col3, #T_ffe14_row7_col4, #T_ffe14_row7_col5, #T_ffe14_row7_col6, #T_ffe14_row7_col7, #T_ffe14_row8_col0, #T_ffe14_row8_col1, #T_ffe14_row8_col2, #T_ffe14_row8_col3, #T_ffe14_row8_col4, #T_ffe14_row8_col5, #T_ffe14_row8_col6, #T_ffe14_row8_col7, #T_ffe14_row9_col0, #T_ffe14_row9_col1, #T_ffe14_row9_col2, #T_ffe14_row9_col3, #T_ffe14_row9_col4, #T_ffe14_row9_col5, #T_ffe14_row9_col6, #T_ffe14_row9_col7, #T_ffe14_row10_col0, #T_ffe14_row10_col1, #T_ffe14_row10_col2, #T_ffe14_row10_col3, #T_ffe14_row10_col4, #T_ffe14_row10_col5, #T_ffe14_row10_col6, #T_ffe14_row10_col7, #T_ffe14_row11_col0, #T_ffe14_row11_col1, #T_ffe14_row11_col2, #T_ffe14_row11_col3, #T_ffe14_row11_col4, #T_ffe14_row11_col5, #T_ffe14_row11_col6, #T_ffe14_row11_col7, #T_ffe14_row12_col0, #T_ffe14_row12_col1, #T_ffe14_row12_col2, #T_ffe14_row12_col3, #T_ffe14_row12_col4, #T_ffe14_row12_col5, #T_ffe14_row12_col6, #T_ffe14_row12_col7, #T_ffe14_row13_col0, #T_ffe14_row13_col1, #T_ffe14_row13_col2, #T_ffe14_row13_col3, #T_ffe14_row13_col4, #T_ffe14_row13_col5, #T_ffe14_row13_col6, #T_ffe14_row13_col7, #T_ffe14_row14_col0, #T_ffe14_row14_col1, #T_ffe14_row14_col2, #T_ffe14_row14_col3, #T_ffe14_row14_col4, #T_ffe14_row14_col5, #T_ffe14_row14_col6, #T_ffe14_row14_col7 {
#   text-align: left;
# }
# #T_ffe14_row0_col1, #T_ffe14_row0_col2, #T_ffe14_row0_col3, #T_ffe14_row0_col4, #T_ffe14_row0_col5, #T_ffe14_row0_col6, #T_ffe14_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ffe14_row0_col8, #T_ffe14_row1_col8, #T_ffe14_row2_col8, #T_ffe14_row3_col8, #T_ffe14_row4_col8, #T_ffe14_row5_col8, #T_ffe14_row6_col8, #T_ffe14_row7_col8, #T_ffe14_row8_col8, #T_ffe14_row9_col8, #T_ffe14_row10_col8, #T_ffe14_row11_col8, #T_ffe14_row12_col8, #T_ffe14_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ffe14_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ffe14">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ffe14_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ffe14_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ffe14_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ffe14_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ffe14_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ffe14_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ffe14_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ffe14_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_ffe14_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ffe14_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_ffe14_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_ffe14_row0_col1" class="data row0 col1" >0.7724</td>
#       <td id="T_ffe14_row0_col2" class="data row0 col2" >0.5680</td>
#       <td id="T_ffe14_row0_col3" class="data row0 col3" >0.7724</td>
#       <td id="T_ffe14_row0_col4" class="data row0 col4" >0.7326</td>
#       <td id="T_ffe14_row0_col5" class="data row0 col5" >0.7402</td>
#       <td id="T_ffe14_row0_col6" class="data row0 col6" >0.6833</td>
#       <td id="T_ffe14_row0_col7" class="data row0 col7" >0.6969</td>
#       <td id="T_ffe14_row0_col8" class="data row0 col8" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_ffe14_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_ffe14_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_ffe14_row1_col1" class="data row1 col1" >0.7590</td>
#       <td id="T_ffe14_row1_col2" class="data row1 col2" >0.5643</td>
#       <td id="T_ffe14_row1_col3" class="data row1 col3" >0.7590</td>
#       <td id="T_ffe14_row1_col4" class="data row1 col4" >0.7251</td>
#       <td id="T_ffe14_row1_col5" class="data row1 col5" >0.7278</td>
#       <td id="T_ffe14_row1_col6" class="data row1 col6" >0.6631</td>
#       <td id="T_ffe14_row1_col7" class="data row1 col7" >0.6802</td>
#       <td id="T_ffe14_row1_col8" class="data row1 col8" >0.0240</td>
#     </tr>
#     <tr>
#       <th id="T_ffe14_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_ffe14_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_ffe14_row2_col1" class="data row2 col1" >0.7252</td>
#       <td id="T_ffe14_row2_col2" class="data row2 col2" >0.5538</td>
#       <td id="T_ffe14_row2_col3" class="data row2 col3" >0.7252</td>
#       <td id="T_ffe14_row2_col4" class="data row2 col4" >0.6886</td>
#       <td id="T_ffe14_row2_col5" class="data row2 col5" >0.6919</td>
#       <td id="T_ffe14_row2_col6" class="data row2 col6" >0.6115</td>
#       <td id="T_ffe14_row2_col7" class="data row2 col7" >0.6281</td>
#       <td id="T_ffe14_row2_col8" class="data row2 col8" >0.0670</td>
#     </tr>
#     <tr>
#       <th id="T_ffe14_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_ffe14_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_ffe14_row3_col1" class="data row3 col1" >0.7052</td>
#       <td id="T_ffe14_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_ffe14_row3_col3" class="data row3 col3" >0.7052</td>
#       <td id="T_ffe14_row3_col4" class="data row3 col4" >0.6724</td>
#       <td id="T_ffe14_row3_col5" class="data row3 col5" >0.6743</td>
#       <td id="T_ffe14_row3_col6" class="data row3 col6" >0.5886</td>
#       <td id="T_ffe14_row3_col7" class="data row3 col7" >0.6023</td>
#       <td id="T_ffe14_row3_col8" class="data row3 col8" >0.0640</td>
#     </tr>
#     <tr>
#       <th id="T_ffe14_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_ffe14_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_ffe14_row4_col1" class="data row4 col1" >0.6843</td>
#       <td id="T_ffe14_row4_col2" class="data row4 col2" >0.5384</td>
#       <td id="T_ffe14_row4_col3" class="data row4 col3" >0.6843</td>
#       <td id="T_ffe14_row4_col4" class="data row4 col4" >0.6737</td>
#       <td id="T_ffe14_row4_col5" class="data row4 col5" >0.6586</td>
#       <td id="T_ffe14_row4_col6" class="data row4 col6" >0.5607</td>
#       <td id="T_ffe14_row4_col7" class="data row4 col7" >0.5815</td>
#       <td id="T_ffe14_row4_col8" class="data row4 col8" >0.0210</td>
#     </tr>
#     <tr>
#       <th id="T_ffe14_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_ffe14_row5_col0" class="data row5 col0" >Decision Tree Classifier</td>
#       <td id="T_ffe14_row5_col1" class="data row5 col1" >0.6790</td>
#       <td id="T_ffe14_row5_col2" class="data row5 col2" >0.4562</td>
#       <td id="T_ffe14_row5_col3" class="data row5 col3" >0.6790</td>
#       <td id="T_ffe14_row5_col4" class="data row5 col4" >0.6544</td>
#       <td

# %% [markdown]
# What you see above is a table of the models that pycaret has, and the performance of each model using different metrics 🤩
# depending on the problem you are trying to solve, you can use different metrics to evaluate the performance of the model 🔍

# %%
print(best)  # best is the model that pycaret has chosen for us
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='sqrt',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_samples_leaf=1,
#                      min_samples_split=2, min_weight_fraction_leaf=0.0,
#                      monotonic_cst=None, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=123, verbose=0,
#                      warm_start=False)

# %% [markdown]
# Now we will use the best model to make predictions on the test set 💻

# %%
predictions = predict_model(best, data)  # predict_model is a function that will help us to make predictions on the test set
print(predictions.sample(5).to_string())  # sample(5) is a function that will help us to print 5 random rows from the predictions dataframe
# Out:
# <style type="text/css">
# </style>
# <table id="T_30884">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30884_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_30884_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_30884_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_30884_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_30884_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_30884_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_30884_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_30884_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30884_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_30884_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_30884_row0_col1" class="data row0 col1" >0.9299</td>
#       <td id="T_30884_row0_col2" class="data row0 col2" >0.9951</td>
#       <td id="T_30884_row0_col3" class="data row0 col3" >0.9299</td>
#       <td id="T_30884_row0_col4" class="data row0 col4" >0.9321</td>
#       <td id="T_30884_row0_col5" class="data row0 col5" >0.9294</td>
#       <td id="T_30884_row0_col6" class="data row0 col6" >0.9038</td>
#       <td id="T_30884_row0_col7" class="data row0 col7" >0.9045</td>
#     </tr>
#   </tbody>
# </table>
#           RI     Na    Mg    Al         Si     K     Ca    Ba    Fe  Type  prediction_label  prediction_score
# 166  1.52151  11.03  1.71  1.56  73.440002  0.58  11.62  0.00  0.00     5                 5              1.00
# 199  1.51609  15.01  0.00  2.51  73.050003  0.05   8.83  0.53  0.00     7                 7              0.94
# 31   1.51747  12.84  3.50  1.14  73.269997  0.56   8.55  0.00  0.00     1                 1              1.00
# 128  1.52068  13.55  2.09  1.67  72.180000  0.53   9.57  0.27  0.17     2                 2              1.00
# 93   1.51590  13.24  3.34  1.47  73.099998  0.39   8.22  0.00  0.00     2                 2              0.79

# %% [markdown]
# Now it's time to try to use pycaret for a regression problem 📈
# let's import the library for the regression problem and the dataset

# %%
from pycaret.regression import *
Data = get_data('diamond')
# Out:
#    Carat Weight    Cut Color Clarity Polish Symmetry Report  Price
# 0          1.10  Ideal     H     SI1     VG       EX    GIA   5169
# 1          0.83  Ideal     H     VS1     ID       ID   AGSL   3470
# 2          0.85  Ideal     H     SI1     EX       EX    GIA   3183
# 3          0.91  Ideal     E     SI1     VG       VG    GIA   4370
# 4          0.83  Ideal     G     SI1     EX       EX    GIA   3171

# %% [markdown]
# Just like the classification problem, we will use the setup function to prepare the data for the model

# %%
S = setup(Data, target = 'Price', session_id = 123)
# Out:
# <style type="text/css">
# #T_ce3c9_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ce3c9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce3c9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ce3c9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce3c9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ce3c9_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ce3c9_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_ce3c9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ce3c9_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ce3c9_row1_col1" class="data row1 col1" >Price</td>
#     </tr>
#     <tr>
#       <th id="T_ce3c9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ce3c9_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_ce3c9_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_ce3c9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ce3c9_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_ce3c9_row3_col1" class="data row3 col1" >(6000, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_ce3c9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ce3c9_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_ce3c9_row4_col1" class="data row4 col1" >(6000, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_ce3c9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ce3c9_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_ce3c9_row5_col1" class="data row5 col1" >(4200, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_ce3c9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ce3c9_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_ce3c9_row6_col1" class="data row6 col1" >(1800, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_ce3c9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ce3c9_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_ce3c9_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_ce3c9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ce3c9_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_ce3c9_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_ce3c9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ce3c9_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_ce3c9_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ce3c9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ce3c9_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_ce3c9_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_ce3c9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ce3c9_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_ce3c9_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_ce3c9_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ce3c9_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_ce3c9_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_ce3c9_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ce3c9_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_ce3c9_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_ce3c9_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ce3c9_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_ce3c9_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_ce3c9_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ce3c9_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_ce3c9_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_ce3c9_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ce3c9_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_ce3c9_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_ce3c9_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ce3c9_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_ce3c9_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_ce3c9_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_ce3c9_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_ce3c9_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ce3c9_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_ce3c9_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_ce3c9_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ce3c9_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_ce3c9_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_ce3c9_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_ce3c9_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_ce3c9_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_ce3c9_row21_col1" class="data row21 col1" >98d2</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Now it's time to compare the models
Best = compare_models()
# Out:
# <style type="text/css">
# #T_c82e1 th {
#   text-align: left;
# }
# #T_c82e1_row0_col0, #T_c82e1_row1_col0, #T_c82e1_row1_col1, #T_c82e1_row1_col2, #T_c82e1_row1_col3, #T_c82e1_row1_col4, #T_c82e1_row1_col5, #T_c82e1_row1_col6, #T_c82e1_row2_col0, #T_c82e1_row2_col1, #T_c82e1_row2_col2, #T_c82e1_row2_col3, #T_c82e1_row2_col4, #T_c82e1_row2_col5, #T_c82e1_row2_col6, #T_c82e1_row3_col0, #T_c82e1_row3_col1, #T_c82e1_row3_col2, #T_c82e1_row3_col3, #T_c82e1_row3_col4, #T_c82e1_row3_col5, #T_c82e1_row3_col6, #T_c82e1_row4_col0, #T_c82e1_row4_col1, #T_c82e1_row4_col2, #T_c82e1_row4_col3, #T_c82e1_row4_col4, #T_c82e1_row4_col5, #T_c82e1_row4_col6, #T_c82e1_row5_col0, #T_c82e1_row5_col1, #T_c82e1_row5_col2, #T_c82e1_row5_col3, #T_c82e1_row5_col4, #T_c82e1_row5_col5, #T_c82e1_row5_col6, #T_c82e1_row6_col0, #T_c82e1_row6_col1, #T_c82e1_row6_col2, #T_c82e1_row6_col3, #T_c82e1_row6_col4, #T_c82e1_row6_col5, #T_c82e1_row6_col6, #T_c82e1_row7_col0, #T_c82e1_row7_col1, #T_c82e1_row7_col2, #T_c82e1_row7_col3, #T_c82e1_row7_col4, #T_c82e1_row7_col5, #T_c82e1_row7_col6, #T_c82e1_row8_col0, #T_c82e1_row8_col1, #T_c82e1_row8_col2, #T_c82e1_row8_col3, #T_c82e1_row8_col4, #T_c82e1_row8_col5, #T_c82e1_row8_col6, #T_c82e1_row9_col0, #T_c82e1_row9_col1, #T_c82e1_row9_col2, #T_c82e1_row9_col3, #T_c82e1_row9_col4, #T_c82e1_row9_col5, #T_c82e1_row9_col6, #T_c82e1_row10_col0, #T_c82e1_row10_col1, #T_c82e1_row10_col2, #T_c82e1_row10_col3, #T_c82e1_row10_col4, #T_c82e1_row10_col5, #T_c82e1_row10_col6, #T_c82e1_row11_col0, #T_c82e1_row11_col1, #T_c82e1_row11_col2, #T_c82e1_row11_col3, #T_c82e1_row11_col4, #T_c82e1_row11_col5, #T_c82e1_row11_col6, #T_c82e1_row12_col0, #T_c82e1_row12_col1, #T_c82e1_row12_col2, #T_c82e1_row12_col3, #T_c82e1_row12_col4, #T_c82e1_row12_col5, #T_c82e1_row12_col6, #T_c82e1_row13_col0, #T_c82e1_row13_col1, #T_c82e1_row13_col2, #T_c82e1_row13_col3, #T_c82e1_row13_col4, #T_c82e1_row13_col5, #T_c82e1_row13_col6, #T_c82e1_row14_col0, #T_c82e1_row14_col1, #T_c82e1_row14_col2, #T_c82e1_row14_col3, #T_c82e1_row14_col4, #T_c82e1_row14_col5, #T_c82e1_row14_col6, #T_c82e1_row15_col0, #T_c82e1_row15_col1, #T_c82e1_row15_col2, #T_c82e1_row15_col3, #T_c82e1_row15_col4, #T_c82e1_row15_col5, #T_c82e1_row15_col6, #T_c82e1_row16_col0, #T_c82e1_row16_col1, #T_c82e1_row16_col2, #T_c82e1_row16_col3, #T_c82e1_row16_col4, #T_c82e1_row16_col5, #T_c82e1_row16_col6, #T_c82e1_row17_col0, #T_c82e1_row17_col1, #T_c82e1_row17_col2, #T_c82e1_row17_col3, #T_c82e1_row17_col4, #T_c82e1_row17_col5, #T_c82e1_row17_col6, #T_c82e1_row18_col0, #T_c82e1_row18_col1, #T_c82e1_row18_col2, #T_c82e1_row18_col3, #T_c82e1_row18_col4, #T_c82e1_row18_col5, #T_c82e1_row18_col6 {
#   text-align: left;
# }
# #T_c82e1_row0_col1, #T_c82e1_row0_col2, #T_c82e1_row0_col3, #T_c82e1_row0_col4, #T_c82e1_row0_col5, #T_c82e1_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_c82e1_row0_col7, #T_c82e1_row1_col7, #T_c82e1_row2_col7, #T_c82e1_row3_col7, #T_c82e1_row4_col7, #T_c82e1_row5_col7, #T_c82e1_row6_col7, #T_c82e1_row7_col7, #T_c82e1_row8_col7, #T_c82e1_row9_col7, #T_c82e1_row10_col7, #T_c82e1_row11_col7, #T_c82e1_row12_col7, #T_c82e1_row13_col7, #T_c82e1_row14_col7, #T_c82e1_row15_col7, #T_c82e1_row16_col7, #T_c82e1_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_c82e1_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_c82e1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c82e1_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c82e1_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_c82e1_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_c82e1_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_c82e1_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_c82e1_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_c82e1_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_c82e1_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c82e1_level0_row0" class="row_heading level0 row0" >xgboost</th>
#       <td id="T_c82e1_row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
#       <td id="T_c82e1_row0_col1" class="data row0 col1" >669.4844</td>
#       <td id="T_c82e1_row0_col2" class="data row0 col2" >1821212.1477</td>
#       <td id="T_c82e1_row0_col3" class="data row0 col3" >1331.1471</td>
#       <td id="T_c82e1_row0_col4" class="data row0 col4" >0.9826</td>
#       <td id="T_c82e1_row0_col5" class="data row0 col5" >0.0722</td>
#       <td id="T_c82e1_row0_col6" class="data row0 col6" >0.0530</td>
#       <td id="T_c82e1_row0_col7" class="data row0 col7" >0.0290</td>
#     </tr>
#     <tr>
#       <th id="T_c82e1_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_c82e1_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#       <td id="T_c82e1_row1_col1" class="data row1 col1" >719.6871</td>
#       <td id="T_c82e1_row1_col2" class="data row1 col2" >2033874.0284</td>
#       <td id="T_c82e1_row1_col3" class="data row1 col3" >1390.8879</td>
#       <td id="T_c82e1_row1_col4" class="data row1 col4" >0.9809</td>
#       <td id="T_c82e1_row1_col5" class="data row1 col5" >0.0786</td>
#       <td id="T_c82e1_row1_col6" class="data row1 col6" >0.0585</td>
#       <td id="T_c82e1_row1_col7" class="data row1 col7" >0.1530</td>
#     </tr>
#     <tr>
#       <th id="T_c82e1_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_c82e1_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_c82e1_row2_col1" class="data row2 col1" >725.2299</td>
#       <td id="T_c82e1_row2_col2" class="data row2 col2" >2336386.4997</td>
#       <td id="T_c82e1_row2_col3" class="data row2 col3" >1491.5615</td>
#       <td id="T_c82e1_row2_col4" class="data row2 col4" >0.9781</td>
#       <td id="T_c82e1_row2_col5" class="data row2 col5" >0.0785</td>
#       <td id="T_c82e1_row2_col6" class="data row2 col6" >0.0577</td>
#       <td id="T_c82e1_row2_col7" class="data row2 col7" >0.1350</td>
#     </tr>
#     <tr>
#       <th id="T_c82e1_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_c82e1_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_c82e1_row3_col1" class="data row3 col1" >721.5692</td>
#       <td id="T_c82e1_row3_col2" class="data row3 col2" >2747712.1060</td>
#       <td id="T_c82e1_row3_col3" class="data row3 col3" >1593.0198</td>
#       <td id="T_c82e1_row3_col4" class="data row3 col4" >0.9748</td>
#       <td id="T_c82e1_row3_col5" class="data row3 col5" >0.0750</td>
#       <td id="T_c82e1_row3_col6" class="data row3 col6" >0.0551</td>
#       <td id="T_c82e1_row3_col7" class="data row3 col7" >0.0570</td>
#     </tr>
#     <tr>
#       <th id="T_c82e1_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_c82e1_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_c82e1_row4_col1" class="data row4 col1" >870.4619</td>
#       <td id="T_c82e1_row4_col2" class="data row4 col2" >2677900.4116</td>
#       <td id="T_c82e1_row4_col3" class="data row4 col3" >1616.3756</td>
#       <td id="T_c82e1_row4_col4" class="data row4 col4" >0.9744</td>
#       <td id="T_c82e1_row4_col5" class="data row4 col5" >0.0990</td>
#       <td id="T_c82e1_row4_col6" class="data row4 col6" >0.0750</td>
#       <td id="T_c82e1_row4_col7" class="data row4 col7" >0.0450</td>
#     </tr>
#     <tr>
#       <th id="T_c82e1_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_c82e1_row5_col0" class="data row5 col0" >Decision Tree Regressor</td>
#       <td id="T_c82e1_row5_col1" class="data row5 col1" >919.7628</td>
#       <td id="T_c82e1_row5_col2" class="data row5 col2" >3495425.3910</td>
#       <td id="T_c82e1_row5_col3" class="data row5 col3" >1821.5832</td>
#       <td id="T_c82e1_row5_col4" class="data row5 col4" >0.9664</td>
#       <td i

# %%
print(Best)
# Out:
# XGBRegressor(base_score=None, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device='cpu', early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=-1,
#              num_parallel_tree=None, objective='reg:squarederror', ...)

# %% [markdown]
# Now we will use the best model to make predictions on the test set 💻

# %%
Predictions = predict_model(Best, Data)
print(Predictions.sample(5).to_string())
# Out:
# <style type="text/css">
# </style>
# <table id="T_6169c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6169c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6169c_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_6169c_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_6169c_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_6169c_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_6169c_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_6169c_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6169c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6169c_row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
#       <td id="T_6169c_row0_col1" class="data row0 col1" >436.7569</td>
#       <td id="T_6169c_row0_col2" class="data row0 col2" >842835.1498</td>
#       <td id="T_6169c_row0_col3" class="data row0 col3" >918.0605</td>
#       <td id="T_6169c_row0_col4" class="data row0 col4" >0.9919</td>
#       <td id="T_6169c_row0_col5" class="data row0 col5" >0.0545</td>
#       <td id="T_6169c_row0_col6" class="data row0 col6" >0.0391</td>
#     </tr>
#   </tbody>
# </table>
#       Carat Weight        Cut Color Clarity Polish Symmetry Report  Price  prediction_label
# 1201          0.75      Ideal     G    VVS2     EX       EX    GIA   3879       3763.576172
# 1084          1.08      Ideal     F     SI1     VG       VG    GIA   5534       5857.025391
# 2060          1.29  Very Good     G     VS1      G       VG    GIA   9105       9802.951172
# 248           1.19      Ideal     G     VS1     ID       ID   AGSL   8034       8664.810547
# 5603          1.01  Very Good     E     SI1     VG       VG    GIA   5384       5259.361816

# %% [markdown]
# A quick explanation about the metrics used in the regression problem:
#
# MAE: Mean Absolute Error (will give us the average of the absolute differences between the predicted and actual values) | The lower the better
# MSE: Mean Squared Error (will give us the average of the squared differences between the predicted and actual values) | The lower the better
# RMSE: Root Mean Squared Error (will give us the square root of the mean squared error) | The lower the better
# R2: R-squared (will give us the percentage of the variance in the dependent variable that is explained by the independent variables) | The higher the better

# %% [markdown]
# Thank you for following this tutorial, I hope you found it useful and informative 🌟
# if you have any questions or suggestions, please feel free to ask me 😄
# Linkedin: https://www.linkedin.com/notifications/?filter=all
